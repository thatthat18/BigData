# %% [markdown]
# $$\frac{du_1(t)}{dt} = f_1(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$\frac{du_2(t)}{dt} = f_2(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$...$$
# $$\frac{du_n(t)}{dt} = f_n(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
#
# $$ u_1(0) = u_1^0, u_1(0) = u_2^0, ..., u_n(0) = u_n^0  $$

# %% [markdown]
# $$ \hat u_1(t_k), \hat u_2(t_k), ... \hat u_n(t_k), k=1,...,N $$

# %% [markdown]
# $$J(\theta_1,\theta_2,...,\theta_m) = \sum_{k=1}^{N} \sum_{i=1}^{n} (u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k))^2 $$

# %% [markdown]
# $$\frac{u_1(t + h) - u_1(t)}{h} = f_1(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$\frac{u_2(t + h) - u_2(t)}{h} = f_2(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$...$$
# $$\frac{u_n(t + h) - u_n(t)}{h} = f_n(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
#
# $$ u_1(0) = u_1^0, u_1(0) = u_2^0, ..., u_n(0) = u_n^0  $$

# %% [markdown]
# $$u_1(t + h) = u_1(t) + f_1(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)h$$
# $$u_2(t + h) = u_2(t) + f_2(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)h$$
# $$...$$
# $$u_n(t + h) = u_n(t) + f_n(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)h$$
#
# $$ u_1(0) = u_1^0, u_1(0) = u_2^0, ..., u_n(0) = u_n^0  $$

# %% [markdown]
# $$u_1(t_{k+1}) = u_1(t_k) + f_1(t,u_1(t_k),u_2(t_k),..,u_n(t_k),\theta_1,\theta_2,...,\theta_m)(t_{k+1} - t_k)$$
# $$u_2(t_{k+1}) = u_2(t_k) + f_2(t,u_1(t_k),u_2(t_k),..,u_n(t_k),\theta_1,\theta_2,...,\theta_m)(t_{k+1} - t_k)$$
# $$...$$
# $$u_n(t_{k+1}) = u_n(t_k) + f_n(t,u_1(t_k),u_2(t_k),..,u_n(t_k),\theta_1,\theta_2,...,\theta_m)(t_{k+1} - t_k)$$
#
# $$ u_1(t_0) = u_1^0, u_1(t_0) = u_2^0, ..., u_n(t_0) = u_n^0  $$

# %% [markdown]
# $$J(\theta_1,\theta_2,...,\theta_m) = \sum_{k=1}^{N} \sum_{i=1}^{n} (u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k))^2 $$

# %% [markdown]
# $$J(\theta_1,\theta_2,...,\theta_m) = \sum_{k=1}^{N} \sum_{i=1}^{n} w_i(u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k))^2 $$

# %% [markdown]
# $$J(\theta_1,\theta_2,...,\theta_m) = \sum_{k=1}^{N} \sum_{i=1}^{n} \bigg (\frac{u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k)}{\hat u_i(t_k)}\bigg)^2 $$

# %% [markdown]
# $$\nabla J(\theta_1,\theta_2,...,\theta_m) = \bigg(\frac{dJ(\theta_1,\theta_2,...,\theta_m)}{d\theta_1}, \frac{dJ(\theta_1,\theta_2,...,\theta_m)}{d\theta_2}, ...,\frac{dJ(\theta_1,\theta_2,...,\theta_m)}{d\theta_m} \bigg)^{T}$$

# %% [markdown]
# $$\theta_1^{(j+1)} = \theta_1^{(j)} - \lambda^{(j)} \frac{dJ(\theta_1^{(j)},\theta_2^{(j)},...,\theta_m^{(j)})}{d\theta_1}$$
# $$\theta_2^{(j+1)} = \theta_2^{(j)} - \lambda^{(j)} \frac{dJ(\theta_1^{(j)},\theta_2^{(j)},...,\theta_m^{(j)})}{d\theta_2}$$
# $$...$$
# $$\theta_m^{(j+1)} = \theta_m^{(j)} - \lambda^{(j)} \frac{dJ(\theta_1^{(j)},\theta_2^{(j)},...,\theta_m^{(j)})}{d\theta_m}$$
#
#
# $$\theta_1^{(0)},\theta_2^{(0)},..., \theta_m^{(0)}$$

# %% [markdown]
# $$\frac{J(\theta_1,\theta_2,...,\theta_m)}{d\theta_j} = 2 \sum_{k=1}^{N} \sum_{i=1}^{n} (u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k)) \frac{du_i(t_k, \theta_1,\theta_2,...,\theta_m)}{d\theta_j} $$

# %% [markdown]
# $$\frac{du_1(t)}{dt} = f_1(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$\frac{du_2(t)}{dt} = f_2(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
# $$...$$
# $$\frac{du_n(t)}{dt} = f_n(t,u_1(t),u_2(t),..,u_n(t),\theta_1,\theta_2,...,\theta_m)$$
#
# $$ u_1(0) = u_1^0, u_1(0) = u_2^0, ..., u_n(0) = u_n^0  $$

# %% [markdown]
# $$\frac{J(\theta_1,\theta_2,...,\theta_m)}{d\theta_j} = 2 \sum_{k=1}^{N} \sum_{i=1}^{n} (u_i(t_k, \theta_1,\theta_2,...,\theta_m) - \hat u_i(t_k)) u_{i,j}(t_k) $$

# %% [markdown]
# $$\frac{du_{1,j}}{dt} = \frac{df_1}{du_1} u_{1,j} + \frac{df_1}{du_2} u_{2,j} + ... + \frac{df_1}{du_n} u_{n,j} + \frac{df_1}{d\theta_j} $$
# $$\frac{du_{2,j}}{dt} = \frac{df_2}{du_1} u_{1,j} + \frac{df_2}{du_2} u_{2,j} + ... + \frac{df_2}{du_n} u_{n,j} + \frac{df_2}{d\theta_j} $$
# $$...$$
# $$\frac{du_{n,j}}{dt} = \frac{df_n}{du_1} u_{1,j} + \frac{df_n}{du_2} u_{2,j} + ... + \frac{df_n}{du_n} u_{n,j} + \frac{df_n}{d\theta_j} $$
#
# $$ u_{1,j}(0) = 0, u_{2,j}(0) = 0, ..., u_{n,j}(0) = 0$$

# %% [markdown]
# $$\frac{dx(t,a,b)}{dt} = -b^2 y(t,a,b)$$
# $$\frac{dy(t,a,b)}{dt} = a^2 x(t,a,b)$$
#
# $$x' = -b^2 y$$
# $$y' = a^2 x$$
#
# $$x(0) = 1$$
# $$y(0) = 0$$

# %% [markdown]
# $$ x(t,a,b) = cos(abt) $$
# $$ y(t,a,b) = \frac{a}{b}sin(abt)$$

# %% [markdown]
# $$\frac{dx_a(t,a,b)}{dt} = (-b^2 y(t,a,b))' = -b^2 y_a(t,a,b) $$
# $$\frac{dy_a(t,a,b)}{dt} = (a^2 x(t,a,b))' = 2a x(t,a,b) + a^2 x_a(t,a,b) $$
# $$ x_a(0) = 0, y_a(0) = 0 $$

# %% [markdown]
# $$ x_a(t,a,b) = -btsin(abt) $$
# $$ y_a(t,a,b) = \frac{sin(abt)}{b} + atcos(abt) $$

# %% [markdown]
# $$\frac{dx_b(t,a,b)}{dt} = (-b^2 y(t,a,b))' = -2 b y(t,a,b) - b^2y_b(t,a,b) $$
# $$\frac{dy_b(t,a,b)}{dt} = (a^2 x(t,a,b))' = a^2 x_b(t,a,b) $$
# $$ x_b(0) = 0, y_b(0) = 0 $$

# %% [markdown]
# $$ x_b(t,a,b) = -atsin(abt)$$
# $$ y_b(t,a,b) = \frac{a^2 t cos(abt)}{b} - \frac{a sin(abt)}{b^2}$$

# %% [markdown]
# $$J(a,b) = (x(t_1,a,b) - \hat x(t_1))^2 + (y(t_1,a,b) - \hat y(t_1))^2 + (x(t_2,a,b) - \hat x(t_2))^2 + (y(t_2,a,b) - \hat y(t_2))^2 $$

# %% [markdown]
# $$\frac{dJ(a,b)}{da} = 2(x(t_1,a,b) - \hat x(t_1))x_a(t_1,a,b) + 2(y(t_1,a,b) - \hat y(t_1))y_a(t_1,a,b) + 2(x(t_2,a,b) - \hat x(t_2))x_a(t_2,a,b) + 2(y(t_2,a,b) - \hat y(t_2))y_a(t,a,b) $$
#
# $$\frac{dJ(a,b)}{db} = 2(x(t_1,a,b) - \hat x(t_1))x_b(t_1,a,b) + 2(y(t_1,a,b) - \hat y(t_1))y_b(t_1,a,b) + 2(x(t_2,a,b) - \hat x(t_2))x_b(t_2,a,b) + 2(y(t_2,a,b) - \hat y(t_2))y_b(t,a,b) $$
